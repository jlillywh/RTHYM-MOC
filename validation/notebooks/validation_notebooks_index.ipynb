# %% [markdown]
# # RTHYM-MOC Validation Notebooks
#
# Empirical and cross-engine verification walkthroughs. Pytest under `tests/` is the CI
# source of truth; these notebooks are interactive mirrors.
#
# Reference datasets live in [`validation/datasets/`](../datasets/).
#
# [![Launch Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/jlillywh/RTHYM-MOC/main?labpath=validation%2Fnotebooks%2Fvalidation_notebooks_index.ipynb)

# %% [markdown]
# ## Recommended order
#
# | Notebook | Trust model | Pytest mirror |
# |----------|-------------|---------------|
# | [grid_scaling_verification.ipynb](grid_scaling_verification.ipynb) | Analytical (Courant grid) | `test_grid_scaling_long_pipe.py` |
# | [bergant_adelaide_verification.ipynb](bergant_adelaide_verification.ipynb) | Independent (lab rig) | `test_dvcm_bergant_adelaide_*.py` |
#
# Additional notebooks remain under [`examples/`](../../examples/) for legacy Binder URLs — see
# [`docs/validation_notebook_coverage.md`](../../docs/validation_notebook_coverage.md).

# %%
from _notebook_setup import bootstrap_validation_notebook
import rthym_moc

root, tests, validation = bootstrap_validation_notebook()
print(f"Repo: {root}")
print(f"rthym_moc {rthym_moc.__version__}")
